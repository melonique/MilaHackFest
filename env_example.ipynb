# %%
# Load environment variables from .env file
from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv()

# Access the environment variables
token = os.getenv('QTOKEN')

print(f"token: {token}")
# Out:
# token: _T_eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJpZCI6MjA3NywiZXhwIjoxNzY2MzQyNjAxLjc2MTIzNTV9.PYsEqAZp0BydNQa9YXfUNVh79oYoqz2I9_oIMFmyQtqeLmNSKRfbTzlmkfln0LXXK70fay7eoLU2A3ssYYSlYA
